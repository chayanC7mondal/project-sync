# %%
# pip install -U google-genai

from google import genai

# --- SET YOUR API KEY HERE (replace with your new one) ---
API_KEY = "AIzaSyAVBQQmLyoZ0ke0hx_OH8IKvRW0OaSEsa8"

# Initialize Gemini client
client = genai.Client(api_key=API_KEY)

def translate_to_odia(text: str) -> str:
    """
    Translate English text to Odia (ଓଡ଼ିଆ) using Gemini 2.5 Flash.
    Uses a professional translation prompt for formal tone.
    """
    prompt = f"""
You are a professional linguist and translator specializing in English to Odia (ଓଡ଼ିଆ) translation.
Your task is to translate the given text accurately and naturally into formal Odia, while preserving
the original tone, intent, and meaning.

Guidelines:
- Use standard Odia grammar and spelling.
- Maintain professional tone suitable for official, academic, or business communication.
- Do not add explanations, transliterations, or comments.
- Do not mix English and Odia unless absolutely necessary (e.g., technical terms or brand names).
- Keep formatting (line breaks, punctuation, numbering) consistent with the source text.

Text to translate:
{text}

Provide only the Odia translation below:
"""

    # Generate content using Gemini 2.5 Flash
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )

    # Extract the text safely
    if hasattr(response, "text"):
        return response.text.strip()
    elif hasattr(response, "output"):
        return str(response.output).strip()
    else:
        return str(response).strip()

# --- Example Usage ---
if __name__ == "__main__":
    english_text = "Please submit the project report by Monday morning."
    odia_translation = translate_to_odia(english_text)
    print("🔤 English:", english_text)
    print("🕉️ Odia:", odia_translation)
# Out:
# 🔤 English: Please submit the project report by Monday morning.
# 🕉️ Odia: ଦୟାକରି ପ୍ରକଳ୍ପ ରିପୋର୍ଟ ସୋମବାର ସକାଳ ସୁଦ୍ଧା ଦାଖଲ କରନ୍ତୁ।
